# %%
import pandas as pd
from sqlalchemy import create_engine, text

engine = create_engine('postgresql+psycopg2://postgres:12345@localhost:5432/dw_eletronicos')

valores_perdido_devolucao = """

                    select 'R$ ' || round(sum(valor_devolvido), 2) as valor_total_devolucoes
                    from dw.fato_devolucoes;

               """

df = pd.read_sql(valores_perdido_devolucao, engine)

df.head()
# Out:
#   valor_total_devolucoes
# 0           R$ 557210.04
